# %%
import csv
import pandas as pd
import numpy as np
# Out:
# /Users/CharlotteLi/social-media-survey/notebooks

# %%
df = pd.read_csv (r'../Socialdistancingthroughsocialm (2).csv')
df.columns
df.rename(columns={"Have you moved out of school housing?": "moveOut",
                   "If you have already moved out and are off-campus, when did you move out?": "moveOutDate",
                   "Where is your home (geographic location)? If you are within the U.S., please respond with a state. If you are outside the U.S., please respond with a country.":"homeState",
                   "What was your daily average screen time during the week of March 1–March 8, 2020? (as reported in hours and minutes). Please write “N/A” if there is no data for that week.":"mar1-8Avg",
                   "What was your total SOCIAL NETWORKING time during the week of March 1–March 8, 2020? (as reported in hours and minutes). Please write “N/A” if there is no data for that week.":"mar1-8Total",
                   "What was your daily average screen time during the week of March 8–March 15, 2020? (as reported in hours and minutes). Please write “N/A” if there is no data for that week.":"mar8-15Avg",
                   "What was your total SOCIAL NETWORKING time during the week of March 8–March 15, 2020? (as reported in hours and minutes). Please write “N/A” if there is no data for that week.":"mar8-15Total",
                   "What was your daily average screen time during the week of March 15–March 22, 2020? (as reported in hours and minutes). Please write “N/A” if there is no data for that week.":"mar15-22Avg",
                   "What was your total SOCIAL NETWORKING time during the week of March 15–March 22, 2020? (as reported in hours and minutes). Please write “N/A” if there is no data for that week.":"mar15-22Total",
                   "What are your five most-used apps for any week PRIOR TO that of March 8–March 15? Please rank them in the order of most-used to least-used, with your most-used app listed first. Please write “N/A” if there is no data for that week.":"beforeTop5",
                   "What are your five most-used apps for the week of March 15–March 22? Please rank them in the order of most-used to least-used, with your most-used app listed first. Please write “N/A” if there is no data for that week.":"top5",
                   "On average, how long have you spent on any video service platform (i.e. Facetime, Messenger video, Zoom, WhatsApp video, etc.) during this last week (March 15–March 22, 2020)?":"avgSocialMediaTime",
                   "Through which social media groups/pages do you see the most content related to the coronavirus and its effects on various aspects of life? (i.e. a WhatsApp group chat, a Facebook group, a Facebook class page, etc.) Separate with semicolons.":"coronaSocialMedia",
                   "How do you find out about coronavirus-related news?":"coronaNews",
                   "Would you like to opt-in to sharing contact info to be contacted for future stories? (By default your email is private, but if you select yes, you may be contacted for a related story).":"contactRelease",
                   "Have you found yourself using social media or applications in a way that you would otherwise not have considered? (i.e. starting a relationship online, having a Zoom party, re-downloading childhood videogames, or anything that you would be willing to share)":"newUsage"
                  })
# Out:
#     Reference #    Status         School email address  \
# 0      13960920  Complete          amh2316@barnard.edu
# 1      13957404  Complete         mam2558@columbia.edu
# 2      13951078  Complete          mv2796@columbia.edu
# 3      13948233  Complete          rhb2143@barnard.edu
# 4      13948047  Complete         mga2145@columbia.edu
# 5      13947756  Complete         ieb2122@columbia.edu
# 6      13945282  Complete          cc4058@columbia.edu
# 7      13944931  Complete          tll2128@barnard.edu
# 8      13942145  Complete         mmc2268@columbia.edu
# 9      13940012  Complete           lt2763@barnard.edu
# 10     13939961  Complete         aeo2147@columbia.edu
# 11     13938118  Complete          nms2196@barnard.edu
# 12     13937296  Complete          mwf2122@barnard.edu
# 13     13934483  Complete         jam2449@columbia.edu
# 14     13933422  Complete          ko2472@columbia.edu
# 15     13933342  Complete          ahg2156@barnard.edu
# ...
